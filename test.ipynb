# %%
import os
from box.exceptions import BoxValueError
import yaml
from srs.cnnClassifier.utils import logger
import json
import joblib
from ensure import ensure_annotations
from box import ConfigBox
from pathlib import Path
from typing import Any
import base64
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 from box.exceptions import BoxValueError
#       3 import yaml
# ----> 4 from cnnClassifier import logger
#       5 import json
#       6 import joblib
#
# ImportError: cannot import name 'logger' from 'cnnClassifier' (D:\data_science\kidney_disease_classification\src\cnnClassifier\__init__.py)

# %%
from cnnClassifier.utils import logger

logger.info("Hello!")
# Out:
# [2023-12-19 15:28:42,677: INFO: 1351692355: Hello!]

# %%
from cnnClassifier.pipeline.prediction import PredictionPipeline

predict = PredictionPipeline("Normal.jpg").predict()
print(predict)
# Out:
# 1/1 [==============================] - 0s 154ms/step
# [0]
# [{'image': 'Normal'}]

# %%
import os
path =  './artifacts/data_ingestion/raw/kidney-ct-scan-image/Tumor'

# %%
import os
countN = 0
countT = 0
for root, dirs, files in os.walk(path):
    for name in files:
        if(PredictionPipeline(os.path.join(root, name)).predict()[0]["image"] == "Normal"):
            countN += 1
        else:
            countT += 1
# Out:
# 1/1 [==============================] - 0s 156ms/step
# [1]
# 1/1 [==============================] - 0s 161ms/step
# [1]
# 1/1 [==============================] - 0s 162ms/step
# [1]
# 1/1 [==============================] - 0s 152ms/step
# [1]
# 1/1 [==============================] - 0s 160ms/step
# [1]
# 1/1 [==============================] - 0s 157ms/step
# [1]
# 1/1 [==============================] - 0s 157ms/step
# [1]
# 1/1 [==============================] - 0s 163ms/step
# [1]
# 1/1 [==============================] - 0s 158ms/step
# [1]
# 1/1 [==============================] - 0s 157ms/step
# [0]
# 1/1 [==============================] - 0s 161ms/step
# [1]
# 1/1 [==============================] - 0s 153ms/step
# [1]
# 1/1 [==============================] - 0s 159ms/step
# [1]
# 1/1 [==============================] - 0s 157ms/step
# [1]
# ---------------------------------------------------------------------------
# ...

# %%
print(countT, countN)
# Out:
# 13 1

# %%
# Out:
# 90
